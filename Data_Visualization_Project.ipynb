# %% [markdown]
# <a href="https://colab.research.google.com/github/Abubakar919666/Python/blob/main/Data_Visualization_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **Question 01**

# %%
# Load and Display Data → Read the dataset and print the first 5 rows.
data = pd.read_csv('covid_19_country_wise_latest.csv')
data.head()
# Out:
#    Unnamed: 0 Country/Region  Confirmed Deaths  Recovered  Active  New cases  \
# 0           0    Afghanistan      36263   1269      25198    9796      106.0
# 1           1        Albania       4880    144       2745    1991      117.0
# 2           2        Algeria      27973   1163      18837    7973      616.0
# 3           3        Andorra        907     52        803      52       10.0
# 4           4         Angola        950     41        242     667       18.0
#
#    New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0        10.0             18                3.50                  69.49
# 1         6.0             63                2.95                  56.25
# 2         8.0            749                4.16                  67.34
# 3         0.0              0                5.73                  88.53
# 4         1.0              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# ...

# %%
data.tail()
# Out:
#      Unnamed: 0      Country/Region  Confirmed Deaths  Recovered  Active  \
# 182         182  West Bank and Gaza      10621     78       3752    6791
# 183         183      Western Sahara         10      1          8       1
# 184         184               Yemen       1691    483        833     375
# 185         185              Zambia       4552    140       2815    1597
# 186         186            Zimbabwe       2704    non        542    2126
#
#      New cases  New deaths  New recovered  Deaths / 100 Cases  \
# 182      152.0         2.0              0                0.73
# 183        0.0         0.0              0               10.00
# 184       10.0         4.0             36               28.56
# 185       71.0         1.0            465                3.08
# 186      192.0         2.0             24                1.33
#
#      Recovered / 100 Cases  Deaths / 100 Recovered  Confirmed last week  \
# 182                  35.33                    2.08                 8916
# ...

# %% [markdown]
# # **Question 02**

# %%
# Set the Dataset index is Unnamed: 0
data.set_index("Unnamed: 0", inplace=True)
data.head()
# Out:
#            Country/Region  Confirmed Deaths  Recovered  Active  New cases  \
# Unnamed: 0
# 0             Afghanistan      36263   1269      25198    9796      106.0
# 1                 Albania       4880    144       2745    1991      117.0
# 2                 Algeria      27973   1163      18837    7973      616.0
# 3                 Andorra        907     52        803      52       10.0
# 4                  Angola        950     41        242     667       18.0
#
#             New deaths  New recovered  Deaths / 100 Cases  \
# Unnamed: 0
# 0                 10.0             18                3.50
# 1                  6.0             63                2.95
# 2                  8.0            749                4.16
# 3                  0.0              0                5.73
# 4                  1.0              0                4.32
#
#             Recovered / 100 Cases  Deaths / 100 Recovered  \
# Unnamed: 0
# 0                           69.49                    5.04
# ...

# %%
# Now replace the index column Unnamed: 0 name with index
data.rename_axis("index", inplace=True)
data.head()
# Out:
#       Country/Region  Confirmed Deaths  Recovered  Active  New cases  \
# index
# 0        Afghanistan      36263   1269      25198    9796      106.0
# 1            Albania       4880    144       2745    1991      117.0
# 2            Algeria      27973   1163      18837    7973      616.0
# 3            Andorra        907     52        803      52       10.0
# 4             Angola        950     41        242     667       18.0
#
#        New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# index
# 0            10.0             18                3.50                  69.49
# 1             6.0             63                2.95                  56.25
# 2             8.0            749                4.16                  67.34
# 3             0.0              0                5.73                  88.53
# 4             1.0              0                4.32                  25.47
#
#        Deaths / 100 Recovered  Confirmed last week  1 week change  \
# index
# ...

# %% [markdown]
# # **Question 03**

# %%
# Function to replace whitespace in column names with underscores
def replace_whitespace(Data):

    # Replace whitespaces with underscores in column names
    data.columns = data.columns.str.replace(' ', '_')

    # Return the updated DataFrame
    return data


data = replace_whitespace(data)

data.head()
# Out:
#       Country/Region  Confirmed Deaths  Recovered  Active  New_cases  \
# index
# 0        Afghanistan      36263   1269      25198    9796      106.0
# 1            Albania       4880    144       2745    1991      117.0
# 2            Algeria      27973   1163      18837    7973      616.0
# 3            Andorra        907     52        803      52       10.0
# 4             Angola        950     41        242     667       18.0
#
#        New_deaths  New_recovered  Deaths_/_100_Cases  Recovered_/_100_Cases  \
# index
# 0            10.0             18                3.50                  69.49
# 1             6.0             63                2.95                  56.25
# 2             8.0            749                4.16                  67.34
# 3             0.0              0                5.73                  88.53
# 4             1.0              0                4.32                  25.47
#
#        Deaths_/_100_Recovered  Confirmed_last_week  1_week_change  \
# index
# ...

# %%
data.columns
# Out:
# Index(['Country/Region', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'New_cases', 'New_deaths', 'New_recovered', 'Deaths_/_100_Cases',
#        'Recovered_/_100_Cases', 'Deaths_/_100_Recovered',
#        'Confirmed_last_week', '1_week_change', '1_week_%_increase',
#        'WHO_Region'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Country/Region             object
# Confirmed                   int64
# Deaths                     object
# Recovered                   int64
# Active                      int64
# New_cases                 float64
# New_deaths                float64
# New_recovered               int64
# Deaths_/_100_Cases        float64
# Recovered_/_100_Cases     float64
# Deaths_/_100_Recovered    float64
# Confirmed_last_week         int64
# 1_week_change               int64
# 1_week_%_increase         float64
# WHO_Region                 object
# dtype: object

# %%
data.isnull().sum()
# Out:
# Country/Region             0
# Confirmed                  0
# Deaths                     0
# Recovered                  0
# Active                     0
# New_cases                 10
# New_deaths                10
# New_recovered              0
# Deaths_/_100_Cases         0
# Recovered_/_100_Cases      0
# Deaths_/_100_Recovered     0
# Confirmed_last_week        0
# 1_week_change              0
# 1_week_%_increase          0
# WHO_Region                 0
# dtype: int64

# %%
# fill the nan values with the mean of the column
data.fillna(data.mean())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-c5c75795220a> in <cell line: 0>()
#       1 # fill the nan values with the mean of the column
# ----> 2 data.fillna(data.mean())
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   11691         **kwargs,
#   11692     ):
# > 11693         result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11694         if isinstance(result, Series):
#   11695             result = result.__finalize__(self, method="mean")
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   12418         **kwargs,
#   12419     ) -> Series | float:
# > 12420         return self._stat_function(
#   12421             "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12422         )
#
# ...

# %%
# Fill NaN values with the mean for numeric columns only
data[data.select_dtypes(include=['number']).columns] = data.select_dtypes(include=['number']).fillna(data.mean())

# Check the updated dataset
print(data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-8d8e127bf5e3> in <cell line: 0>()
#       1 # Fill NaN values with the mean for numeric columns only
# ----> 2 data[data.select_dtypes(include=['number']).columns] = data.select_dtypes(include=['number']).fillna(data.mean())
#       3
#       4 # Check the updated dataset
#       5 print(data)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   11691         **kwargs,
#   11692     ):
# > 11693         result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11694         if isinstance(result, Series):
#   11695             result = result.__finalize__(self, method="mean")
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   12418         **kwargs,
# ...

# %%
# Select only numeric columns
numeric_columns = data.select_dtypes(include=['number']).columns

# Fill NaN values in numeric columns with the mean
data.fillna(data[numeric_columns].mean())

# Check the updated dataset
print(data)
# Out:
#            Country/Region  Confirmed Deaths  Recovered  Active  New_cases  \
# index
# 0             Afghanistan      36263   1269      25198    9796      106.0
# 1                 Albania       4880    144       2745    1991      117.0
# 2                 Algeria      27973   1163      18837    7973      616.0
# 3                 Andorra        907     52        803      52       10.0
# 4                  Angola        950     41        242     667       18.0
# ...                   ...        ...    ...        ...     ...        ...
# 182    West Bank and Gaza      10621     78       3752    6791      152.0
# 183        Western Sahara         10      1          8       1        0.0
# 184                 Yemen       1691    483        833     375       10.0
# 185                Zambia       4552    140       2815    1597       71.0
# 186              Zimbabwe       2704    non        542    2126      192.0
#
# ...

# %%
# Count the number of unique countries in the dataset.
data['Country/Region'].nunique()
# Out:
# 187

# %%
# Check if there are any duplicate country entries and remove them if needed
data['Country/Region'].duplicated()
# Out:
# index
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 182    False
# 183    False
# 184    False
# 185    False
# 186    False
# Name: Country/Region, Length: 187, dtype: bool

# %%
# Find the mean
numerical_columns = data.select_dtypes(include=['float64', 'int64'])
print(numerical_columns.mean())
# Out:
# Confirmed                 8.813094e+04
# Recovered                 5.063148e+04
# Active                    3.400194e+04
# New_cases                 1.282740e+03
# New_deaths                3.040113e+01
# New_recovered             9.338128e+02
# Deaths_/_100_Cases        3.019519e+00
# Recovered_/_100_Cases     6.482053e+01
# Deaths_/_100_Recovered             inf
# Confirmed_last_week       7.868248e+04
# 1_week_change             9.448460e+03
# 1_week_%_increase         1.360620e+01
# dtype: float64

# %%
# Find the mean, median, and standard deviation of total cases.
data.describe()
# Out:
#           Confirmed     Recovered        Active     New_cases   New_deaths  \
# count  1.870000e+02  1.870000e+02  1.870000e+02    177.000000   177.000000
# mean   8.813094e+04  5.063148e+04  3.400194e+04   1282.740113    30.401130
# std    3.833187e+05  1.901882e+05  2.133262e+05   5864.213495   123.232977
# min    1.000000e+01  0.000000e+00  0.000000e+00      0.000000     0.000000
# 25%    1.114000e+03  6.265000e+02  1.415000e+02      4.000000     0.000000
# 50%    5.059000e+03  2.815000e+03  1.600000e+03     58.000000     1.000000
# 75%    4.046050e+04  2.260600e+04  9.149000e+03    420.000000     6.000000
# max    4.290259e+06  1.846641e+06  2.816444e+06  56336.000000  1076.000000
#
#        New_recovered  Deaths_/_100_Cases  Recovered_/_100_Cases  \
# count     187.000000          187.000000             187.000000
# mean      933.812834            3.019519              64.820535
# std      4197.719635            3.454302              26.287694
# ...

# %%
# # Set pandas to display all rows
# pd.set_option('display.max_rows', None)

# # Assuming 'data' is your DataFrame
# print(data['Deaths'])

# # Optionally, reset the display setting to the default
# pd.reset_option('display.max_rows')

# %%
# Find out the string in Deaths

data['Deaths_numeric'] = pd.to_numeric(data['Deaths'], errors='coerce')
strings_in_deaths = data[data['Deaths_numeric'].isna()]

print(strings_in_deaths)
# Out:
#       Country/Region  Confirmed Deaths  Recovered  Active  New_cases  \
# index
# 186         Zimbabwe       2704    non        542    2126      192.0
#
#        New_deaths  New_recovered  Deaths_/_100_Cases  Recovered_/_100_Cases  \
# index
# 186           2.0             24                1.33                  20.04
#
#        Deaths_/_100_Recovered  Confirmed_last_week  1_week_change  \
# index
# 186                      6.64                 1713            991
#
#        1_week_%_increase WHO_Region  Deaths_numeric
# index
# 186                57.85     Africa             NaN

# %%
# replace it with the mean of Deaths column

pd.to_numeric(data['Deaths'], errors='coerce')
mean_data = data['Deaths'].mean()
data['Deaths'].fillna(mean_data, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-9a34d9cbbf6e> in <cell line: 0>()
#       2
#       3 pd.to_numeric(data['Deaths'], errors='coerce')
# ----> 4 mean_data = data['Deaths'].mean()
#       5 data['Deaths'].fillna(mean_data, inplace=True)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/series.py in mean(self, axis, skipna, numeric_only, **kwargs)
#    6547         **kwargs,
#    6548     ):
# -> 6549         return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#    6550
#    6551     @doc(make_doc("median", ndim=1))
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   12418         **kwargs,
#   12419     ) -> Series | float:
# > 12420         return self._stat_function(
#   12421             "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
# ...

# %%
data['Deaths'].unique()
non_numeric = data[~data['Deaths'].str.isnumeric()]
print(non_numeric)
# Out:
#       Country/Region  Confirmed Deaths  Recovered  Active  New_cases  \
# index
# 186         Zimbabwe       2704    non        542    2126      192.0
#
#        New_deaths  New_recovered  Deaths_/_100_Cases  Recovered_/_100_Cases  \
# index
# 186           2.0             24                1.33                  20.04
#
#        Deaths_/_100_Recovered  Confirmed_last_week  1_week_change  \
# index
# 186                      6.64                 1713            991
#
#        1_week_%_increase WHO_Region  Deaths_numeric
# index
# 186                57.85     Africa             NaN

# %%
data['Deaths'] = pd.to_numeric(data['Deaths'], errors='coerce')

# Step 5: Calculate the mean of the 'Deaths' column, ignoring NaN values
mean_data = data['Deaths'].mean()

# Step 6: Replace NaN values with the mean of 'Deaths'
data['Deaths'].fillna(mean_data, inplace=True)
# Out:
# <ipython-input-22-edc54c471970>:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Deaths'].fillna(mean_data, inplace=True)

# %%
data['Deaths'].fillna(mean_data)

data['Deaths']
# Out:
# index
# 0      1269.000000
# 1       144.000000
# 2      1163.000000
# 3        52.000000
# 4        41.000000
#           ...
# 182      78.000000
# 183       1.000000
# 184     483.000000
# 185     140.000000
# 186    3516.129032
# Name: Deaths, Length: 187, dtype: float64

# %%
# Change the datatype of column Deaths
data['Deaths'].astype(int)
# Out:
# index
# 0      1269
# 1       144
# 2      1163
# 3        52
# 4        41
#        ...
# 182      78
# 183       1
# 184     483
# 185     140
# 186    3516
# Name: Deaths, Length: 187, dtype: int64

# %% [markdown]
# # **Question 12**

# %%
# Calculate total number of Death in worldwide
data['Deaths'].sum().astype(int)
# Out:
# 657516

# %%
# Calculate total number of Recovered all over the world
data['Recovered'].sum()
# Out:
# 9468087

# %% [markdown]
# # **Question 13**

# %%
data[data['Confirmed'] > 1000000]
# Out:
#       Country/Region  Confirmed    Deaths  Recovered   Active  New_cases  \
# index
# 23            Brazil    2442375   87618.0    1846641   508116    23284.0
# 79             India    1480073   33408.0     951166   495499    44457.0
# 173               US    4290259  148011.0    1325804  2816444    56336.0
#
#        New_deaths  New_recovered  Deaths_/_100_Cases  Recovered_/_100_Cases  \
# index
# 23          614.0          33728                3.59                  75.61
# 79          637.0          33598                2.26                  64.26
# 173        1076.0          27941                3.45                  30.90
#
#        Deaths_/_100_Recovered  Confirmed_last_week  1_week_change  \
# index
# 23                       4.74              2118646         323729
# 79                       3.51              1155338         324735
# 173                     11.16              3834677         455582
#
#        1_week_%_increase       WHO_Region  Deaths_numeric
# index
# ...

# %%
print(data.loc[data["Confirmed"] > 1000000, ["Country/Region"]].value_counts().sum())
# Out:
# 3

# %% [markdown]
# # **Question 14**

# %%
# Calculate Recovery Rate (Recovered / Confirmed) * 100
data['Recovery_Rate'] = (data['Recovered'] / data['Confirmed']) * 100

# Filter countries with a Recovery Rate above 95%
Recovery_Rate = data.loc[data['Recovery_Rate'] > 95, ['Country/Region']].value_counts().sum()
Recovery_Rate
# Out:
# 12

# %% [markdown]
# # **Question 15**

# %%
# Drop columns name WHO Region and Confirmed
data.drop(['WHO_Region', 'Confirmed'], axis=1)
# Out:
#            Country/Region       Deaths  Recovered  Active  New_cases  \
# index
# 0             Afghanistan  1269.000000      25198    9796      106.0
# 1                 Albania   144.000000       2745    1991      117.0
# 2                 Algeria  1163.000000      18837    7973      616.0
# 3                 Andorra    52.000000        803      52       10.0
# 4                  Angola    41.000000        242     667       18.0
# ...                   ...          ...        ...     ...        ...
# 182    West Bank and Gaza    78.000000       3752    6791      152.0
# 183        Western Sahara     1.000000          8       1        0.0
# 184                 Yemen   483.000000        833     375       10.0
# 185                Zambia   140.000000       2815    1597       71.0
# 186              Zimbabwe  3516.129032        542    2126      192.0
#
#        New_deaths  New_recovered  Deaths_/_100_Cases  Recovered_/_100_Cases  \
# index
# ...

# %% [markdown]
# # **Question 16**

# %%
# Find the Country with the Max Deaths
data.loc[data['Deaths'].idxmax(), 'Country/Region']
# Out:
# 'US'

# %% [markdown]
# # **Question 17**

# %%
# Sort countries by Deaths in descending order
sorted_data = data.sort_values(by="Deaths", ascending=False)
sorted_data[["Country/Region", "Deaths"]]
# Out:
#          Country/Region    Deaths
# index
# 173                  US  148011.0
# 23               Brazil   87618.0
# 177      United Kingdom   45844.0
# 111              Mexico   44022.0
# 85                Italy   35112.0
# ...                 ...       ...
# 19               Bhutan       0.0
# 130    Papua New Guinea       0.0
# 75             Holy See       0.0
# 30             Cambodia       0.0
# 114            Mongolia       0.0
#
# [187 rows x 2 columns]

# %% [markdown]
# # **Question 18**

# %%
# Make new column name Total_cases that have a sum of Deaths, Recovered , Active
data['Total_cases'] = data['Deaths'] + data['Recovered'] + data['Active']
data
# Out:
#            Country/Region  Confirmed       Deaths  Recovered  Active  \
# index
# 0             Afghanistan      36263  1269.000000      25198    9796
# 1                 Albania       4880   144.000000       2745    1991
# 2                 Algeria      27973  1163.000000      18837    7973
# 3                 Andorra        907    52.000000        803      52
# 4                  Angola        950    41.000000        242     667
# ...                   ...        ...          ...        ...     ...
# 182    West Bank and Gaza      10621    78.000000       3752    6791
# 183        Western Sahara         10     1.000000          8       1
# 184                 Yemen       1691   483.000000        833     375
# 185                Zambia       4552   140.000000       2815    1597
# 186              Zimbabwe       2704  3516.129032        542    2126
#
#        New_cases  New_deaths  New_recovered  Deaths_/_100_Cases  \
# index
# ...

# %% [markdown]
# # **Question 19**

# %%
# Calculate Death_Rate for Each Country
data['Death_Rate'] = (data['Deaths'] / data['Total_cases']) * 100
data
# Out:
#            Country/Region  Confirmed       Deaths  Recovered  Active  \
# index
# 0             Afghanistan      36263  1269.000000      25198    9796
# 1                 Albania       4880   144.000000       2745    1991
# 2                 Algeria      27973  1163.000000      18837    7973
# 3                 Andorra        907    52.000000        803      52
# 4                  Angola        950    41.000000        242     667
# ...                   ...        ...          ...        ...     ...
# 182    West Bank and Gaza      10621    78.000000       3752    6791
# 183        Western Sahara         10     1.000000          8       1
# 184                 Yemen       1691   483.000000        833     375
# 185                Zambia       4552   140.000000       2815    1597
# 186              Zimbabwe       2704  3516.129032        542    2126
#
#        New_cases  New_deaths  New_recovered  Deaths_/_100_Cases  \
# index
# ...

# %% [markdown]
# # **Question 20**

# %%
low_death =
# Out:
#   File "<ipython-input-35-c01dd1331fc8>", line 1
#     low_death =
#                ^
# SyntaxError: invalid syntax

# %% [markdown]
# # **Question 21**

# %%
# print head of only 2 columns Country/Region and Death_Rate
data[["Country/Region"	,"Death_Rate"]].head()
# Out:
#       Country/Region  Death_Rate
# index
# 0        Afghanistan    3.499435
# 1            Albania    2.950820
# 2            Algeria    4.157581
# 3            Andorra    5.733186
# 4             Angola    4.315789

# %% [markdown]
# # **Question 22**

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=data, x='Total_cases', y='Deaths', alpha=0.7)
plt.xscale('log')
plt.yscale('log')
plt.xlabel("Total Cases (log scale)")
plt.ylabel("Deaths (log scale)")
plt.title("Total Cases vs Deaths")
plt.show()

# %% [markdown]
# # **Question 23**

# %%
# Save dataset in CSV format.
data.to_csv("updated_covid_data.csv", index=False)
